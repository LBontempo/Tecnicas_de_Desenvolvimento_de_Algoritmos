# %% [markdown]
# Lista 2 Estruturas condicionais (IF, ELIF,ELSE)

# %% [markdown]
# Nome: Lucas Bontempo Limeira dos Santos
#
# Turma: ADS Quinta-Feira
#
# Materia: Tecnicas de desemvolvimento de sistema
#
# ![transferir.png](data:image/png;base64,...)

# %%
#1-Elabore um programa que solicite ao usuário um número real e ao final imprima na tela se o número informado é maior que 10 (dez)

numero = float(input("Digite um numero real: "))

if numero>10:
  print(f"O numero informado foi {numero}, ele é MAIOR que 10!")
# Out:
# Digite um numero real: 5.56

# %%
#2-Escreva um programa que solicite ao usuário um número real e ao final imprima na tela se o número informado é maior ou igual a dez ou menor que 10 (dez)

numero1 = float(input("Digite um numero real: "))

if numero1 > 10:
  print (f"o numero é {numero1} ele é Maior que 10")
elif numero1 < 9:
  print (f"o numero é {numero1}, ele é menor que 10")
elif numero1 == 10:
  print (f"o numero é {numero1}, ele é igual 10")
# Out:
# Digite um numero real: 8.65
# o numero é 8.65, ele é menor que 10

# %%
#3-Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o número informado é maior que dez, se é menor que dez, ou se é igual a dez
numero1 = float(input("Digite um numero real: "))

if numero1 > 10:
  print (f"o numero é {numero1} ele é Maior que 10")
elif numero1 < 9:
  print (f"o numero é {numero1}, ele é menor que 10")
elif numero1 == 10:
  print (f"o numero é {numero1}, ele é igual 10")
numero3 = ("")
# Out:
# Digite um numero real: 4.56
# o numero é 4.56, ele é menor que 10

# %%
#4-Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o número informado é positivo, negativo ou nulo (zero

numero4 = float(input("Digite um numero real: "))

if numero4>0:
  print(f"o numero {numero4} é possitivo!")
elif numero4<0:
  print(f"o numero {numero4} é negativo!")
elif numero4==0:
  print(f"o numero {numero4} é Nulo!")
# Out:
# Digite um numero real: 1.23
# o numero 1.23 é possitivo!

# %%
#5. Elabore um algoritmo que leia um número inteiro e imprima uma das mensagens: é múltiplode 3, ou, não é múltiplo de 3

numero5 = int(input("Digite um número inteiro: "))

if numero5%3==0:
  print(f"o numero {numero5} é multiplo de 3!")
else:
  print(f"o numero {numero5} é NÃO multiplo de 3!")
# Out:
# Digite um número inteiro: 8
# o numero 8 é NÃO multiplo de 3!

# %%
#6-Refazer o exercício anterior, solicitando antes o múltiplo a ser testado

numero6 = int(input("Digite um numero inteiro: "))
multiplo = int(input("Digite o multiplo desejado: "))

if numero6 % multiplo == 0:
  print(f"o numero {numero6} é multiplo de {multiplo}")
else:
  print (f"o numero {numero6} NÃO é multiplo de {multiplo}")
# Out:
# Digite um numero inteiro: 8
# Digite o multiplo desejado: 3
# o numero 8 NÃO é multiplo de 3

# %%
#7-Desenvolva um algoritmo que classifique um número inteiro fornecido pelo usuário como par ou ímpar

numero7 = int(input("Digite um numero inteiro: "))

if numero7 % 2 ==0:
  print(f"o numero é PAR!")
else:
  print(f"o numero é IMPAR!")
# Out:
# Digite um numero inteiro: 5
# o numero é IMPAR!

# %%
#8. Elabore um algoritmo que leia um número, e se ele for maior do que 20, imprimir a metade desse número, caso contrário, imprimir o dobro do número

numero8 = int(input("Digite um numero: "))

if numero8 > 20:
  print(f"a metade desse numero é {numero8/2} ")
elif numero8 < 20:
  print(f"o dobro desse numero é {numero8*2}")
# Out:
# Digite um numero: 5
# o dobro desse numero é 10

# %%
#9. Elabore um algoritmo que leia dois números inteiros e realize a adição; caso o resultado seja maior que 10, imprima o quadrado do resultado, caso contrário, imprima a metade dele

numero9 = int(input("Digite o primeiro numero: "))
numero92 = int(input("Digite o segundo numero: "))

adicao = numero9+numero92

if adicao > 10:
  print(f"o quadrado da soma destes numero é {adicao**2}")
else:
  print(f"a metade da soma destes numero é {adicao/2}")
# Out:
# Digite o primeiro numero: 10
# Digite o segundo numero: 20
# o quadrado da soma destes numero é 900

# %%
'''10. O sistema de avaliação de determinada disciplina é composto por três provas. A primeira
prova tem peso 2, a segunda tem peso 3 e a terceira tem peso 5. Considerando que a
média para aprovação é 6.0, faça um algoritmo para calcular a média final de um aluno
desta disciplina e dizer se o aluno foi aprovado ou não'''

nota1 = float(input("Digite a nota da primeira prova, que tem peso 2: "))
nota2 = float(input("Digite a nota da segunda prova, que tem peso 3: "))
nota3 = float(input("Digite a nota da terceira prova, que tem peso 5: "))

media = ((nota1*2)+(nota2*3)+(nota3*5))/10


if media >= 6:
  print (f"Aluno aprovado com media de: {media}")
elif media <= 6:
  print (f"Aluno foi reprovado com media de: {media}")
else:
  print (f"Erro, contatc o suporte!")
# Out:
# Digite a nota da primeira prova, que tem peso 2: 6
# Digite a nota da segunda prova, que tem peso 3: 5
# Digite a nota da terceira prova, que tem peso 5: 4
# Aluno foi reprovado com media de: 4.7

# %%
#11. Elabore um algoritmo que leia o nome e o peso de duas pessoas e imprima o nome da pessoa mais pesada

nome1 = str(input("Digite o seu nome: "))
peso1 = float(input("Digite seu peso: "))

nome2 = str(input("Digite seu nome: "))
peso2 = float(input("Digite seu peso: "))

if peso1 == peso2:
  print (f"o pesos de {nome1} e {nome2} são iguais")
elif peso1 > peso2:
  print (f"O peso de {nome1} é maior")
else:
  print (f"O peso de {nome2} é maior")
# Out:
# Digite o seu nome: lucas
# Digite seu peso: 80
# Digite seu nome: test
# Digite seu peso: 75
# O peso de lucas é maior

# %%
#12. Elabore um algoritmo que indique se um número digitado está compreendido entre 20 e 90, ou não

numero12 = int(input("Digite um numero: "))

if numero12 >= 20 and numero12 <= 90:
  print(f"o numero está compeendido entre 20 e 90")
else:
  print(f"o numero NÃO está compeendido entre 20 e 90")
# Out:
# Digite um numero: 8
# o numero NÃO está compeendido entre 20 e 90

# %%
#13. Elabore um algoritmo que leia dois números e imprima qual é maior, qual é menor, ou se são iguais

numero13 = int(input("Digite um numero: "))
numero13_2 = int(input("Digite um segundo numero: "))

if numero13 == numero13_2:
  print ("ambos são iguais");
elif numero13 > numero13_2:
  print (f"o primeiro numero: {numero13}, é maior que o segundo numero: {numero13_2}")
else:
  print (f"o segundo numero: {numero13_2}, é maior que o primeiro numero: {numero13}")
# Out:
# Digite um numero: 50
# Digite um segundo numero: 40
# o primeiro numero: 50, é maior que o segundo numero: 40

# %%
'''14. Escreva um programa em linguagem C que solicite ao usuário a média para aprovação
em um curso e em seguida solicite ao usuário o nome, sexo e as 03 notas do aluno e ao
final imprima a frase: "O aluno XXXXX foi aprovado com media YY" considerando o gênero
do(a) aluno(a) e se foi aprovado(a) ou reprovado(a)'''

media14 = float(input("Qual é a media para a aprovação? "))
nome14 = str(input("Qual é o seu nome? "))
sexo14 = str(input("Qual é o seu sexo(M/F)? "))
nota141 = float(input("Qual é sua primeira nota? "))
nota142 = float(input("Qual é sua segunda nota? "))
nota143 = float(input("Qual é sua terceira nota? "))

soma14 = (nota141+nota142+nota143)/3

if sexo14 == "M" and soma14 >= media14:
  print(f"O aluno {nome14} foi aprovado com media: {soma14}")
elif sexo14 == "F" and soma14 >= media14:
  print(f"A aluna {nome14} foi aprovada com media: {soma14}")

if sexo14 == "M" and soma14 < media14:
  print(f"O aluno {nome14} foi reprovado com media: {soma14}")
elif sexo14 == "F" and soma14 < media14:
  print(f"A aluna {nome14} foi reprovada com media: {soma14}")
# Out:
# Qual é a media para a aprovação? 6
# Qual é o seu nome? lucas
# Qual é o seu sexo(M/F)? m
# Qual é sua primeira nota? 7
# Qual é sua segunda nota? 5
# Qual é sua terceira nota? 7
