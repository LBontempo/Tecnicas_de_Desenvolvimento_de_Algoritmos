# %% [markdown]
# <a href="https://colab.research.google.com/github/LBontempo/Tecnicas_de_Desenvolvimento_de_Algoritmos/blob/main/Aula1ADS_LucasB_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nome: Lucas Bontempo Limeira dos Santos
#
# Turma: ADS Quinta-Feira
#
#
# Materia: Tecnicas de desemvolvimento de sistema
#
# ![Python_icon_(black_and_white).svg.png](data:image/png;base64,...)

# %%
print("olá, mundo!")
# Out:
# olá, mundo!

# %%
#operadores
"""
Como usar python como calculadora, abaixo será necessario informar um valor para a variavel a.
"""
print()

a=10
30*5+a-2

type(a)
# Out:
# int

# %%
#divisão

3//10 # é diferente de 3/10
#// barra barra é divisão por inteiro.

#DESAFIO: FAZER UM PROGRAMA QUE ARREDENTE A NOTA, IGUAL A UDF SOBRE OS 5.76

nota = float(input("Digite sua nota: "))
nota = nota//2
print(nota)
# Out:
# Digite sua nota: 5
# 2.0

# %%
"""
operados textuais
concatenação: é juntar usando a virgula.
repetição: é multiplicar usando o *
"""

"Lucas "*3
print("Lucas ",3*50)
faculdade="UDF"
print("Eu estudo no ", faculdade, (3*50))
# Out:
# Lucas  150
# Eu estudo no  UDF 150

# %%
numero_inteiro=int
numero_inteiro=input("digite um numero inteiro")
print(numero_inteiro)
# Out:
# digite um numero inteiro10
# 10
